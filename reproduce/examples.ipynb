# %% [markdown]
# # Examples
#
# How to use the various RAG/HS subroutines.

# %% [markdown]
# ## HS

# %%
from highlight_summarize.hs import HSBaseline

hs = HSBaseline(
    highlighter_model_name="gpt-4.1-mini",
    summarizer_model_name="gpt-4.1-mini",
    temperature=0.2,
    n_trials=1,
    sleep_time_between_retrials=1.0,
    max_sleep_time_between_retrials=600.0,
)
hs({
    "question": "Who is the upstart candidate in Jakarta's election known for social activism?",
    "document_extracted": "Jakarta Election Campaigns Heat Up: Here's How to Understand the System \n\nAs election day in Jakarta draws nearer, candidates are out in force using various strategies to woo voters and prepare to exercise their democratic rights. Citizens make their voices heard as the city vibrates with life. This coverage offers valuable insight into campaign activities while offering an in-depth guide for understanding electoral processes in Jakarta. \n\nInitial Launch of Candidates' Campaign Plans on September 1 \n\nAfter September 1st, when campaign season officially kicked off, candidates have moved swiftly to engage their bases. Amira Bintang, an upstart candidate with extensive social activism experience and promising urban development and public transportation reform as key platforms of her candidacy speech in Jakarta; incumbent Rizal Harahap relies heavily on his track record and highlights all infrastructure projects completed during his term. \n\nCampaign Strategies: From Digital Battlegrounds to Door-toDoor Outreach \n\nCampaign strategies have taken an advanced turn as candidates leverage digital media to reach a wider audience. Hashtags, viral videos, targeted ads and targeted messaging can all play an influential role in changing public opinion with just a tweet or meme. At the grassroots level candidates engage in door-to-door campaigns personalized for individual voters in an attempt to connect. \n\nBintang's interactive app for gathering real-time feedback from citizens about daily commute challenges was applauded as an innovative form of civic engagement, while Harahap launched a series of webinars featuring experts discussing economic growth under his administration. \n\nRallies and Persuasion\nJakartan politicians know the power of an impassioned speech cannot be underrated, and candidates have been taking full advantage of its effectiveness at rallies. Rallies feature vibrant colors, banners and impassioned discourse in an attempt to win converts over. At one high-spirited rally on October 22, Bintang outlined her policy plans for improving education and healthcare to an appreciative crowd while Harahap's rallies often consist of shows of solidarity from various political allies united behind his plea for continuity and stability. \n\nDebates: Clashes Between Visions and Policies \n\nDebates are one of the highlights of Jakarta election campaigns, allowing candidates to outline their platforms and discuss critical issues. On November 5th, citizens witnessed an exhilarating debate between candidates Bintang and Harahap over whether the city was prepared for digital transformation in public services; Bintang advocated an aggressive move toward smart city model while Harahap advocated a more measured approach so as not to alienate less tech-savvy residents. \n\nVoter Engagement: Making Every Vote Count \n\nEnsuring every eligible voter is engaged and informed remains an ongoing challenge for Jakartans. Civil society groups and independent bodies host workshops and publish voter guides to inform voters of their rights and choices, while an annual democracy festival such as that held on November 20 featured interactive exhibits on Jakarta's electoral history as well as mock voting booths for first-time voters. \n\nCampaign Financing: Transparency and Accountability \n\nCampaign financing has always been a contentious topic in elections, and this election cycle is no exception. Bintang's campaign, funded largely through crowdfunders online supporters, stands in stark contrast with Harahap's sophisticated machine backed by both private donors and party funds. To protect democratic decision making processes from any\nundue influences on decision-making processes, Jakarta Election Commission mandated strict reporting and transparency measures during campaign financing decisions. \n\nBefore Election Day: Submit Final Appeals Now \n\nAs election day nears, candidates make their last appeals to voters. Bintang plans a visit through key neighborhoods while Harahap plans a final rally scheduled for late November. Both camps are honing their messaging and policy proposals while encouraging supporters to make an appearance at polling booths on November 8th. \n\nPolling Day: The Final Act of Campaign Activities \n\nOn December 6th, voting booths across Jakarta will open their doors, signalling the culmination of weeks of intense campaigning. Voters will cast their vote and candidates await results that depend on how effective their strategies, speeches and outreach initiatives have been. \n\nJakarta's vibrant election campaign offers an insight into its flourishing democracy. As the city looks ahead to an exciting new chapter in its political history, electoral processes demonstrate the significance of people-power in shaping our collective futures.\n"
})
# Out:
# {'answer_pred': 'Amira Bintang is an upstart candidate known for her extensive social activism experience. Her candidacy speech in Jakarta highlights urban development and public transportation reform as key platforms.',
#  'summarizer_llm_response': "guessed_question='Who is Amira Bintang and what are the main focuses of her candidacy?' answer='Amira Bintang is an upstart candidate known for her extensive social activism experience. Her candidacy speech in Jakarta highlights urban development and public transportation reform as key platforms.'",
#  'summarizer_llm_guessed_question': 'Who is Amira Bintang and what are the main focuses of her candidacy?',
#  'highlighter_extracted': 'Amira Bintang, an upstart candidate with extensive social activism experience and promising urban development and public transportation reform as key platforms of her candidacy speech in Jakarta',
#  'highlighter_llm_response': '- Amira Bintang, an upstart candidate with extensive social activism experience and promising urban development and public transportation reform as key platforms of her candidacy speech in Jakarta',
#  'highlighter_text_extracts': ['Amira Bintang, an upstart candidate with extensive social activism experience and promising urban development and public transportation reform as key platforms of her candidacy speech in Jakarta'],
#  'highlighter_fuzzmatch_scores': [100.0],
#  'highlighter_score': None,
#  'model_name': None,
#  'temperature': 0.2,
#  'llm_response': None,
#  'highlighter_model_name': 'gpt-4.1-mini',
#  'summarizer_model_name': 'gpt-4.1-mini'}

# %%
from highlight_summarize.hs import HSStructuredHighlighter

hs = HSStructuredHighlighter(
     highlighter_model_name="gpt-4.1-mini",
    summarizer_model_name="gpt-4.1-mini",
    temperature=0.2,
    n_trials=1,
    sleep_time_between_retrials=1.0,
    max_sleep_time_between_retrials=600.0,
)
hs({
    "question": "Who is the upstart candidate in Jakarta's election known for social activism?",
    "document_extracted": "Jakarta Election Campaigns Heat Up: Here's How to Understand the System \n\nAs election day in Jakarta draws nearer, candidates are out in force using various strategies to woo voters and prepare to exercise their democratic rights. Citizens make their voices heard as the city vibrates with life. This coverage offers valuable insight into campaign activities while offering an in-depth guide for understanding electoral processes in Jakarta. \n\nInitial Launch of Candidates' Campaign Plans on September 1 \n\nAfter September 1st, when campaign season officially kicked off, candidates have moved swiftly to engage their bases. Amira Bintang, an upstart candidate with extensive social activism experience and promising urban development and public transportation reform as key platforms of her candidacy speech in Jakarta; incumbent Rizal Harahap relies heavily on his track record and highlights all infrastructure projects completed during his term. \n\nCampaign Strategies: From Digital Battlegrounds to Door-toDoor Outreach \n\nCampaign strategies have taken an advanced turn as candidates leverage digital media to reach a wider audience. Hashtags, viral videos, targeted ads and targeted messaging can all play an influential role in changing public opinion with just a tweet or meme. At the grassroots level candidates engage in door-to-door campaigns personalized for individual voters in an attempt to connect. \n\nBintang's interactive app for gathering real-time feedback from citizens about daily commute challenges was applauded as an innovative form of civic engagement, while Harahap launched a series of webinars featuring experts discussing economic growth under his administration. \n\nRallies and Persuasion\nJakartan politicians know the power of an impassioned speech cannot be underrated, and candidates have been taking full advantage of its effectiveness at rallies. Rallies feature vibrant colors, banners and impassioned discourse in an attempt to win converts over. At one high-spirited rally on October 22, Bintang outlined her policy plans for improving education and healthcare to an appreciative crowd while Harahap's rallies often consist of shows of solidarity from various political allies united behind his plea for continuity and stability. \n\nDebates: Clashes Between Visions and Policies \n\nDebates are one of the highlights of Jakarta election campaigns, allowing candidates to outline their platforms and discuss critical issues. On November 5th, citizens witnessed an exhilarating debate between candidates Bintang and Harahap over whether the city was prepared for digital transformation in public services; Bintang advocated an aggressive move toward smart city model while Harahap advocated a more measured approach so as not to alienate less tech-savvy residents. \n\nVoter Engagement: Making Every Vote Count \n\nEnsuring every eligible voter is engaged and informed remains an ongoing challenge for Jakartans. Civil society groups and independent bodies host workshops and publish voter guides to inform voters of their rights and choices, while an annual democracy festival such as that held on November 20 featured interactive exhibits on Jakarta's electoral history as well as mock voting booths for first-time voters. \n\nCampaign Financing: Transparency and Accountability \n\nCampaign financing has always been a contentious topic in elections, and this election cycle is no exception. Bintang's campaign, funded largely through crowdfunders online supporters, stands in stark contrast with Harahap's sophisticated machine backed by both private donors and party funds. To protect democratic decision making processes from any\nundue influences on decision-making processes, Jakarta Election Commission mandated strict reporting and transparency measures during campaign financing decisions. \n\nBefore Election Day: Submit Final Appeals Now \n\nAs election day nears, candidates make their last appeals to voters. Bintang plans a visit through key neighborhoods while Harahap plans a final rally scheduled for late November. Both camps are honing their messaging and policy proposals while encouraging supporters to make an appearance at polling booths on November 8th. \n\nPolling Day: The Final Act of Campaign Activities \n\nOn December 6th, voting booths across Jakarta will open their doors, signalling the culmination of weeks of intense campaigning. Voters will cast their vote and candidates await results that depend on how effective their strategies, speeches and outreach initiatives have been. \n\nJakarta's vibrant election campaign offers an insight into its flourishing democracy. As the city looks ahead to an exciting new chapter in its political history, electoral processes demonstrate the significance of people-power in shaping our collective futures.\n"
})
# Out:
# {'answer_pred': 'Amira Bintang is an upstart candidate in Jakarta known for her extensive social activism experience. Her key campaign platforms focus on urban development and public transportation reform.',
#  'summarizer_llm_response': "guessed_question='Who is Amira Bintang and what are her main campaign platforms in Jakarta?' answer='Amira Bintang is an upstart candidate in Jakarta known for her extensive social activism experience. Her key campaign platforms focus on urban development and public transportation reform.'",
#  'summarizer_llm_guessed_question': 'Who is Amira Bintang and what are her main campaign platforms in Jakarta?',
#  'highlighter_extracted': 'Amira Bintang, an upstart candidate with extensive social activism experience and promising urban development and public transportation reform as key platforms of her candidacy speech in Jakarta;',
#  'highlighter_llm_response': "The upstart candidate in Jakarta's election known for social activism is Amira Bintang.",
#  'highlighter_text_extracts': ['Amira Bintang, an upstart candidate with extensive social activism experience and promising urban development and public transportation reform as key platforms of her candidacy speech in Jakarta;'],
#  'highlighter_fuzzmatch_scores': [100.0],
#  'highlighter_score': None,
#  'model_name': None,
#  'temperature': 0.2,
#  'llm_response': None,
#  'highlighter_model_name': 'gpt-4.1-mini',
#  'summarizer_model_name': 'gpt-4.1-mini'}

# %% [markdown]
# ## Judges

# %%
from highlight_summarize.utils import NOANSWER_PRED
from highlight_summarize.judges import JUDGES

examples = [
    {
        "question": "What motivated Zhao Wei to found WeTech?",
        "answer": "Zhao was motivated by his belief in doing well by doing good.",
        "answer_pred": "Beer",
    },
    {
        "question": "What motivated Zhao Wei to found WeTech?",
        "answer": NOANSWER_PRED,
        "answer_pred": NOANSWER_PRED,
    },
    {
        "question": "What motivated Zhao Wei to found WeTech?",
        "answer": NOANSWER_PRED,
        "answer_pred": "A desire to create a better world",  # Wrong answer.
    },
]

for example in examples:
    print(f"Question: {example['question']}")
    print(f"Answer: {example['answer']}")
    print(f"Predicted Answer: {example['answer_pred']}")
    for judge_name, judge_cls in JUDGES.items():
        judge = judge_cls()
        res = judge(example)
        print(f"{judge_name}")
        print(res)
    print("-" * 40)
    print("\n")
# Out:
# Question: What motivated Zhao Wei to found WeTech?
# Answer: Zhao was motivated by his belief in doing well by doing good.
# Predicted Answer: Beer

# %%
from highlight_summarize.utils import openai_client


import judges
def patched_get_completion(
    messages: list[dict[str, str]],
    model: str,
    temperature: float,
    max_tokens: int,
    seed: int,
    response_format: dict = None,
    response_model = None,
):
    """Monkey-patch the get_completion method to use the openai_client."""
    return openai_client().beta.chat.completions.parse(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
        seed=seed,
        response_format=response_format,
    )
# model_response = self.openai_client().beta.chat.completions.parse(
#             messages=[
#                 #{"role": "system", "content": self.system_prompt},
#                 {"role": "user", "content": user_prompt},
#             ],
#             model=self.model_name,
#             response_format=LLMRatingOutput,
#             temperature=self.temperature,
#         ).choices[0].message.parsed
    

# judges._client.llm_client = my_get_completion
judges.base.get_completion = patched_get_completion

# judges._client.get_completion([], "", 0, 1, 1)

# MTBenchChatBotResponseQuality

judge = judges.MTBenchChatBotResponseQuality(model="gpt-4.1-mini")
a = judge.judge(input="What is the capital of France?", expected="Paris", output="Paris")

judge = judges.ReliableCIRelevance(model="gpt-4.1-mini")
b = judge.judge(
    input="What is the capital of France?",
    expected="Paris",
    output="The capital of France is Paris"
)
# Out:
# Completion: ParsedChatCompletion[NoneType](id='chatcmpl-BgtGvMXDod2uRSipTiH5oBGRlF0V6', choices=[ParsedChoice[NoneType](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[NoneType](content='{"REASONING": "The assistant\'s response is accurate, directly answering the user\'s question with the correct capital of France, \'Paris.\' It is concise and relevant, fulfilling the user\'s request without any unnecessary information. However, the response lacks additional context or detail that could enhance the user\'s understanding, such as mentioning that Paris is the largest city in France or a brief note on its significance. Given the simplicity of the question, the brief answer is sufficient, but a slightly more informative response could improve helpfulness and depth.", "SCORE": "8"}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=None))], created=1749561941, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier=None, system_fingerprint='fp_178c8d546f', usage=CompletionUsage(completion_tokens=112, prompt_tokens=156, total_tokens=268, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Completion: ParsedChatCompletion[NoneType](id='chatcmpl-BgtGzANVVhoxXBn8O0sfQier59ruC', choices=[ParsedChoice[NoneType](finish_reason='stop', index=0, logprobs=None, message=ParsedChatCompletionMessage[NoneType](content='{"REASONING": "The passage directly states the capital of France as Paris, which exactly answers the query without any extraneous information.", "SCORE": "3"}', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None, parsed=None))], created=1749561945, model='gpt-4.1-mini-2025-04-14', object='chat.completion', service_tier=None, system_fingerprint='fp_178c8d546f', usage=CompletionUsage(completion_tokens=36, prompt_tokens=153, total_tokens=189, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
a
# Out:
# Judgment(score='8', reasoning="The assistant's response is accurate, directly answering the user's question with the correct capital of France, 'Paris'. It is concise and relevant, fulfilling the user's request without any unnecessary information. However, the response lacks additional context or detail that could enhance the user's understanding, such as mentioning that Paris is the largest city in France or a brief note on its significance. Given the simplicity of the question, the brief answer is sufficient, but a slightly more informative response could improve helpfulness and depth.")

# %%
b
# Out:
# Judgment(score='3', reasoning='The passage directly states the capital of France as Paris, which exactly answers the query.')
